# %% [markdown]
# # Valores Atipicos
# _______________________________________
#
#
# ## 1. Importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Cargar archivo

# %%
data = pd.read_csv('./Recursos/ventas_totales_sin_nulos.csv')
display(data)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 2.1 Verificar que no hayan valores nulos

# %%
valoresNulos = data.isnull().sum()
print(valoresNulos)

valoresNulosCSV = data.isnull().sum().sum()
print(f'\nValores nulos en el CSV: {valoresNulosCSV}')
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %% [markdown]
# ## 3. Valores atipicos para columna ventas_precios_corrientes
#
# - 3.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data1 = data.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data1['ventas_precios_corrientes'], color='blue', rwidth=0.5)
plt.title('Histograma de Ventas Precios Corrientes')
plt.xlabel('Ventas Precios Corrientes')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# - 3.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data1['ventas_precios_corrientes'])
plt.title('Outliers de Ventas Precios Corrientes')
plt.show()

# %% [markdown]
# - 3.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data1['ventas_precios_corrientes']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por el metodo std no se borra ningun valor, por tanto, el valor que vemos en el boxplot debe corresponder al metodo iqr
outliers = data1[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 214312.62
# Limite inferior permitido : -69832.23
#
# Outliers:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# - 3.3 Obtenemos datos limpios

# %%
data_clean = data1[(y<=limiteSuperior) & (y>=limiteInferior)]
display(data_clean)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 3.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['ventas_precios_corrientes'])
plt.title('Outliers de Ventas Precios Corrientes')
plt.show()

# %% [markdown]
# - 3.5 Metodo IQR (metodo que utiliza boxplot)

# %%
# Encontramos los valores extremos
y = data1["ventas_precios_corrientes"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna el valor atipico que buscamos
outliers = data1[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 192319.35
# Limite inferior permitido : -59178.65
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                 81140696.22   76413721.76
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457                81140696.22  24935747.29      22143208.63
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# ...

# %% [markdown]
# - 3.6 Obtenemos datos limpios

# %%
data_clean_iqr = data1[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 3.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los 4 outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['ventas_precios_corrientes'])
plt.title('Outliers de Ventas Precios Corrientes')
plt.show()

# %% [markdown]
# - 3.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/ventas_precios_corrientes.csv")

# %% [markdown]
# ## 4. Valores atipicos para columna ventas_precios_constantes
#
# - 4.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data2 = data1.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data2['ventas_precios_constantes'], color='blue', rwidth=0.5)
plt.title('Histograma de Ventas Precios Constantes')
plt.xlabel('Ventas Precios Constantes')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# - 4.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data2['ventas_precios_constantes'])
plt.title('Outliers de Ventas Precios Constantes')
plt.show()

# %% [markdown]
# - 4.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data2['ventas_precios_constantes']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por este metodo nos arroja solo 2 registros, mientras que en el boxplot se visualizan 3. Por tanto, es posible que con el
# metodo iqr encontremos los demás outliers
outliers = data2[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")

# Filtramos los datos limpios
data_clean = data2[(y<=limiteSuperior) & (y>=limiteInferior)]
print(f"\n\nDatos Limpios")
display(data_clean)
# Out:
# Limite superior permitido : 40022.91
# Limite inferior permitido : 12104.48
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457               8.114070e+07  24935747.29      22143208.63
# 60      4819479.554               1.545171e+08  46962602.22      46053650.13
#
#     ...      almacen    panaderia       lacteos        carnes  \
# 42  ...  23393038.41  2630487.791  9.592798e+06  8.463266e+06
# 60  ...  37505172.62  4860317.680  1.610477e+07  1.740849e+07
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# ...

# %% [markdown]
# - 4.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['ventas_precios_constantes'])
plt.title('Outliers de Ventas Precios Constantes')
plt.show()

# %% [markdown]
# - 4.5 Metodo IQR (metodo que utiliza boxplot)

# %%
# Encontramos los valores extremos
y = data2["ventas_precios_constantes"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna los 3 valores atipicos que visualizamos al principio con el boxplot
outliers = data2[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 31938.75
# Limite inferior permitido : 18759.95
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 11          11    01/12/2017                    40766.3
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 11                    34084.5                4.076632e+07  4.032029e+07
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 11     4.460368e+05               4.076632e+07  13710305.37      11070098.74
# 42     4.726974e+06               8.114070e+07  24935747.29      22143208.63
# 60     4.819480e+06               1.545171e+08  46962602.22      46053650.13
#
# ...

# %% [markdown]
# - 4.6 Obtenemos datos limpios

# %%
data_clean_iqr = data2[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 4.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['ventas_precios_constantes'])
plt.title('Outliers de Ventas Precios Constantes')
plt.show()

# %% [markdown]
# - 4.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/ventas_precios_constantes.csv")

# %% [markdown]
# ## 5. Valores atipicos para columna salon_ventas
#
# - 5.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data3 = data2.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data3['salon_ventas'], color='blue', rwidth=0.5)
plt.title('Histograma de Salon Ventas')
plt.xlabel('Ventas Salon Ventas')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# - 5.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data3['salon_ventas'])
plt.title('Outliers de Salon Ventas')
plt.show()

# %% [markdown]
# - 5.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data3['salon_ventas']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por este metodo no contamos con ningun registro
outliers = data3[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")

# Filtramos los datos limpios
data_clean = data3[(y<=limiteSuperior) & (y>=limiteInferior)]
print(f"\n\nDatos Limpios")
display(data_clean)
# Out:
# Limite superior permitido : 197606560.24
# Limite inferior permitido : -45934387.42
#
# Outliers:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]
#
#
# Datos Limpios
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# ...

# %% [markdown]
# - 5.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['salon_ventas'])
plt.title('Outliers de Salon Ventas')
plt.show()

# %% [markdown]
# - 5.5 Metodo IQR (metodo que utiliza boxplot)

# %%
# Encontramos los valores extremos
y = data3["salon_ventas"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna los 3 valores atipicos que visualizamos al principio con el boxplot
outliers = data3[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 170440082.58
# Limite inferior permitido : -32001350.25
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
# ...

# %% [markdown]
# - 5.6 Obtenemos datos limpios

# %%
data_clean_iqr = data3[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 5.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['salon_ventas'])
plt.title('Outliers de Salon Ventas')
plt.show()

# %% [markdown]
# - 5.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/salon_ventas.csv")

# %% [markdown]
# ## 6. Valores atipicos para columna tarjetas_debito
#
# - 6.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data4 = data3.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data4['tarjetas_debito'], color='blue', rwidth=0.5)
plt.title('Histograma de Tarjetas Debito')
plt.xlabel('Tarjetas Debito')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# - 6.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data4['tarjetas_debito'])
plt.title('Outliers de Tarjetas Debito')
plt.show()

# %% [markdown]
# - 6.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data4['tarjetas_debito']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por este metodo no contamos con ningun registro
outliers = data4[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")

# Filtramos los datos limpios
data_clean = data4[(y<=limiteSuperior) & (y>=limiteInferior)]
print(f"\n\nDatos Limpios")
display(data_clean)
# Out:
# Limite superior permitido : 58179494.95
# Limite inferior permitido : -18390283.64
#
# Outliers:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]
#
#
# Datos Limpios
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# ...

# %% [markdown]
# - 6.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['tarjetas_debito'])
plt.title('Outliers de Tarjetas Debito')
plt.show()

# %% [markdown]
# - 6.5 Metodo IQR (metodo que utiliza boxplot)

# %%
# Encontramos los valores extremos
y = data4["tarjetas_debito"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna los valores atipicos que visualizamos al principio con el boxplot
outliers = data4[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 50952216.58
# Limite inferior permitido : -15349161.05
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# ...

# %% [markdown]
# - 6.6 Obtenemos datos limpios

# %%
data_clean_iqr = data4[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 6.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['tarjetas_debito'])
plt.title('Outliers de Tarjetas Debito')
plt.show()

# %% [markdown]
# - 6.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/tarjetas_debito.csv")

# %% [markdown]
# ## 7. Valores atipicos para columna tarjetas_credito
#
# - 7.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data5 = data4.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data5['tarjetas_credito'], color='blue', rwidth=0.5)
plt.title('Histograma de Tarjetas Credito')
plt.xlabel('Tarjetas Credito')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# - 7.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data5['tarjetas_credito'])
plt.title('Outliers de Tarjetas Credito')
plt.show()

# %% [markdown]
# - 7.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data5['tarjetas_credito']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por este metodo no contamos con ningun registro
outliers = data5[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")

# Filtramos los datos limpios
data_clean = data5[(y<=limiteSuperior) & (y>=limiteInferior)]
print(f"\n\nDatos Limpios")
display(data_clean)
# Out:
# Limite superior permitido : 72217546.59
# Limite inferior permitido : -17886155.9
#
# Outliers:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]
#
#
# Datos Limpios
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# ...

# %% [markdown]
# - 7.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['tarjetas_credito'])
plt.title('Outliers de Tarjetas Credito')
plt.show()

# %% [markdown]
# - 7.5 Metodo IQR (metodo que utiliza boxplot)

# %%
# Encontramos los valores extremos
y = data5["tarjetas_credito"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna los valores atipicos que visualizamos al principio con el boxplot
outliers = data5[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 63856184.06
# Limite inferior permitido : -16515482.22
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 63  ...  49991675.91  6746166.557  19309461.59  22877841.24
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# ...

# %% [markdown]
# - 7.6 Obtenemos datos limpios

# %%
data_clean_iqr = data5[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 58          58    01/11/2021                   141702.0
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 7.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['tarjetas_credito'])
plt.title('Outliers de Tarjetas Credito')
plt.show()

# %% [markdown]
# - 7.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/tarjetas_credito.csv")

# %% [markdown]
# ## 8. Valores atipicos para columna ventas_totales_grupo_articulos
#
# - 8.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data6 = data5.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data6['subtotal_ventas_alimentos_bebidas'], color='blue', rwidth=0.5)
plt.title('Histograma de Subtotal Ventas Alimentos Bebidas')
plt.xlabel('Subtotal Ventas Alimentos Bebidas')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# - 8.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data6['subtotal_ventas_alimentos_bebidas'])
plt.title('Outliers de Subtotal Ventas Alimentos Bebidas')
plt.show()

# %% [markdown]
# - 8.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data6['subtotal_ventas_alimentos_bebidas']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por este metodo no contamos con ningun registro
outliers = data6[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")

# Filtramos los datos limpios
data_clean = data6[(y<=limiteSuperior) & (y>=limiteInferior)]
print(f"\n\nDatos Limpios")
display(data_clean)
# Out:
# Limite superior permitido : 142419354.1
# Limite inferior permitido : -33370218.28
#
# Outliers:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]
#
#
# Datos Limpios
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# ...

# %% [markdown]
# - 8.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['subtotal_ventas_alimentos_bebidas'])
plt.title('Outliers de Subtotal Ventas Alimentos Bebidas')
plt.show()

# %% [markdown]
# - 8.5 Metodo IQR (metodo que utiliza boxplot)

# %%
# Encontramos los valores extremos
y = data6["subtotal_ventas_alimentos_bebidas"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna los valores atipicos que visualizamos al principio con el boxplot
outliers = data6[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 114548006.92
# Limite inferior permitido : -11790048.95
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 62                    24612.4                 168982502.3   164321107.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59     5.116431e+06                183983151.9  56640033.15      55432191.37
# ...

# %% [markdown]
# - 8.6 Obtenemos datos limpios

# %%
data_clean_iqr = data6[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 56          56    01/09/2021                   123002.3
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 8.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['subtotal_ventas_alimentos_bebidas'])
plt.title('Outliers de Subtotal Ventas Alimentos Bebidas')
plt.show()

# %% [markdown]
# - 8.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/subtotal_ventas_alimentos_bebidas.csv")

# %% [markdown]
# ## 9. Valores atipicos para columna bebidas
#
# - 9.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data7 = data6.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data7['bebidas'], color='blue', rwidth=0.5)
plt.title('Histograma de Bebidas')
plt.xlabel('Bebidas')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# - 9.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data7['bebidas'])
plt.title('Outliers de Bebidas')
plt.show()

# %% [markdown]
# - 9.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data7['bebidas']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por este metodo encontramos 1 registro
outliers = data7[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")

# Filtramos los datos limpios
data_clean = data7[(y<=limiteSuperior) & (y>=limiteInferior)]
print(f"\n\nDatos Limpios")
display(data_clean)
# Out:
# Limite superior permitido : 26484419.88
# Limite inferior permitido : -8726956.89
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# ...

# %% [markdown]
# - 9.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['bebidas'])
plt.title('Outliers de Bebidas')
plt.show()

# %% [markdown]
# - 9.5 Metodo IQR (metodo que utiliza boxplot)
#
# Nota. En este caso, por cualquiera de los dos metodos encontrabamos los outliers correspondientes. Sin embargo, por practica, decidí seguir la estructura y utilizar ambos metodos

# %%
# Encontramos los valores extremos
y = data7["bebidas"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna los valores atipicos que visualizamos al principio con el boxplot
outliers = data7[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 22825184.45
# Limite inferior permitido : -6724636.75
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# ...

# %% [markdown]
# - 9.6 Obtenemos datos limpios

# %%
data_clean_iqr = data7[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 9.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['bebidas'])
plt.title('Outliers de Bebidas')
plt.show()

# %% [markdown]
# - 9.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/bebidas.csv")

# %% [markdown]
# ## 10. Valores atipicos para columna panaderia
#
# - 10.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data8 = data7.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data8['panaderia'], color='blue', rwidth=0.5)
plt.title('Histograma de Panaderia')
plt.xlabel('Panaderia')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# - 10.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data8['panaderia'])
plt.title('Outliers de Panaderia')
plt.show()

# %% [markdown]
# - 10.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data8['panaderia']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por este metodo no encontramos registros
outliers = data8[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")

# Filtramos los datos limpios
data_clean = data8[(y<=limiteSuperior) & (y>=limiteInferior)]
print(f"\n\nDatos Limpios")
display(data_clean)
# Out:
# Limite superior permitido : 6984940.29
# Limite inferior permitido : -1843701.22
#
# Outliers:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]
#
#
# Datos Limpios
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# ...

# %% [markdown]
# - 10.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['panaderia'])
plt.title('Outliers de Panaderia')
plt.show()

# %% [markdown]
# - 10.5 Metodo IQR (metodo que utiliza boxplot)

# %%
# Encontramos los valores extremos
y = data8["panaderia"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna los valores atipicos que visualizamos al principio con el boxplot
outliers = data8[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 5344003.47
# Limite inferior permitido : -946571.91
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 62                    24612.4                 168982502.3   164321107.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59     5.116431e+06                183983151.9  56640033.15      55432191.37
# ...

# %% [markdown]
# - 10.6 Obtenemos datos limpios

# %%
data_clean_iqr = data8[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 56          56    01/09/2021                   123002.3
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 10.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['panaderia'])
plt.title('Outliers de Panaderia')
plt.show()

# %% [markdown]
# - 10.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/panaderia.csv")

# %% [markdown]
# ## 11. Valores atipicos para columna lacteos
#
# - 11.1 Histograma de variables cuantitativas

# %%
# Generamos una copia de data
data9 = data8.copy()

fig = plt.figure(figsize = (10,10))
plt.hist(x=data9['lacteos'], color='blue', rwidth=0.5)
plt.title('Histograma de Lacteos')
plt.xlabel('Lacteos')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# - 11.2 Diagrama caja bigote

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(data9['lacteos'])
plt.title('Outliers de Lacteos')
plt.show()

# %% [markdown]
# - 11.3 Metodo desviacion estandar

# %%
# Encontramos los valores extremos
y = data9['lacteos']
limiteSuperior = y.mean() + 3*y.std()
limiteInferior = y.mean() - 3*y.std()

print(f"Limite superior permitido : {round(limiteSuperior,2)}")
print(f"Limite inferior permitido : {round(limiteInferior,2)}")

# Encontramos Outliers
# Vemos que por este metodo no encontramos registros
outliers = data9[(y>limiteSuperior) | (y<limiteInferior)]
print(f"\nOutliers:\n{outliers}")

# Filtramos los datos limpios
data_clean = data9[(y<=limiteSuperior) & (y>=limiteInferior)]
print(f"\n\nDatos Limpios")
display(data_clean)
# Out:
# Limite superior permitido : 22295332.46
# Limite inferior permitido : -5847189.47
#
# Outliers:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]
#
#
# Datos Limpios
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# ...

# %% [markdown]
# - 11.4 Realizamos diagrama bigote con data_clean

# %%
# Seguimos visualizando el outlier
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean['lacteos'])
plt.title('Outliers de Lacteos')
plt.show()

# %% [markdown]
# - 11.5 Metodo IQR (metodo que utiliza boxplot)

# %%
# Encontramos los valores extremos
y = data9["lacteos"]

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3

iqr = percentile75 - percentile25

limiteSuperiorIQR = percentile75 + 1.5 * iqr
limiteInferiorIQR = percentile25 - 1.5 * iqr

print(f"Limite superior permitido : {round(limiteSuperiorIQR,2)}")
print(f"Limite inferior permitido : {round(limiteInferiorIQR,2)}")

# Encontramos Outliers
# En este caso nos retorna los valores atipicos que visualizamos al principio con el boxplot
outliers = data9[(y>limiteSuperiorIQR) | (y<limiteInferiorIQR)]
print(f"\nOutliers:\n{outliers}")
# Out:
# Limite superior permitido : 19940661.05
# Limite inferior permitido : -5569362.3
#
# Outliers:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# ...

# %% [markdown]
# - 11.6 Obtenemos datos limpios

# %%
data_clean_iqr = data9[(y<=limiteSuperiorIQR) & (y>=limiteInferiorIQR)]
display(data_clean_iqr)
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# - 11.7 Realizamos diagrama bigote con data_clean_iqr

# %%
# Los outliers identificados en un principio ahora ya no son parte del df
fig = plt.figure(figsize = (10,6))
plt.boxplot(data_clean_iqr['lacteos'])
plt.title('Outliers de Lacteos')
plt.show()

# %% [markdown]
# - 11.8 Guardamos el df sin valores atipicos

# %%
data_clean_iqr.to_csv("./Filtros/Act3.1/lacteos.csv")
