# %% [markdown]
# #Actividad Extracción de Datos
# -------------------------------------
#
# ####Jose Israel Perez Ontiveros | A01423294

# %% [markdown]
# ## 1. Importar librerias

# %%
import pandas as pd

# %% [markdown]
# ## 2. Carga de archivo XLSX

# %%
df = pd.read_excel('./Recursos/Inmuebles.xlsx')
display(df)
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2 2004-01-01       Local     Venta     Girona       185.0
# 2              3 2004-01-01     Oficina  Alquiler     Girona        82.0
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5 2004-01-02       Suelo     Venta  Tarragona       152.0
# ...          ...        ...         ...       ...        ...         ...
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
# 3334        3335 2007-04-30       Suelo     Venta  Tarragona        78.0
# 3335        3336 2007-04-30        Piso  Alquiler  Barcelona        88.0
# 3336        3337 2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# 0        2133903.0  2004-06-19   Carmen
# ...

# %% [markdown]
# # 3. Filtros

# %% [markdown]
# ### 3.1 Eliminar la fila “0” de “Unnamed” y Eliminar la columna “0” y la columna “Referencia”

# %%
## Eliminar la fila 0 (en realidad, la fila con índice 0)
filtro1 = df.drop(0)

# Eliminar las columnas "0" y "Referencia"
filtro1 = df.drop(columns=['0', 'Referencia'])

# Imprimir el DataFrame resultante
display(filtro1)

# Guardar filtro en CSV
filtro1.to_csv("./Filtros/Act1.3/Filtro1.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/israperez/Documents/Concentracion/ExtracciondeDatos/Actividad_1_3_(Extracción_de_Datos).ipynb Cell 8 line 5
#       <a href='vscode-notebook-cell:/Users/israperez/Documents/Concentracion/ExtracciondeDatos/Actividad_1_3_%28Extracci%C3%B3n_de_Datos%29.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> filtro1 = df.drop(0)
#       <a href='vscode-notebook-cell:/Users/israperez/Documents/Concentracion/ExtracciondeDatos/Actividad_1_3_%28Extracci%C3%B3n_de_Datos%29.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> # Eliminar las columnas "0" y "Referencia"
# ----> <a href='vscode-notebook-cell:/Users/israperez/Documents/Concentracion/ExtracciondeDatos/Actividad_1_3_%28Extracci%C3%B3n_de_Datos%29.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> filtro1 = df.drop(columns=['0', 'Referencia'])
# ...

# %% [markdown]
# ### 3.2 Todos las registros de “Fecha Alta : igual a 2007-04-29 00:00:00 y a 2004-01-02 00:00:00

# %%
filtro2 = df.loc[(df['Fecha_Alta'] == '2007-04-29 00:00:00') | (df['Fecha_Alta'] == '2004-01-02 00:00:00')]

# Imprimir los registros seleccionados
display(filtro2)

# Guardar filtro en CSV
filtro2.to_csv("./Filtros/Act1.3/Filtro2.csv")
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5 2004-01-02       Suelo     Venta  Tarragona       152.0
# 3331        3332 2007-04-29     Oficina     Venta     Lleida       190.0
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
#
#       Precio Venta Fecha Venta Vendedor
# 3              NaN  2004-04-27    Jesús
# 4         185000.0  2004-07-10    María
# 3331     1031320.0         NaT      NaN
# 3332     1450644.0         NaT      NaN
# 3333      454080.0         NaT      NaN

# %% [markdown]
# ### 3.3 Todos los registros de “ Tipo: parking, local, industrial y piso”

# %%
filtro3 = df[df['Tipo'].isin(['Parking', 'Local', 'Industrial', 'Piso'])]
display(filtro3)

# Guardar filtro en CSV
filtro3.to_csv("./Filtros/Act1.3/Filtro3.csv")
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2 2004-01-01       Local     Venta     Girona       185.0
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 5              6 2004-01-03  Industrial  Alquiler     Girona       131.0
# 6              7 2004-01-03     Parking  Alquiler  Tarragona         NaN
# ...          ...        ...         ...       ...        ...         ...
# 3330        3331 2007-04-27       Local     Venta     Girona       110.0
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
# 3335        3336 2007-04-30        Piso  Alquiler  Barcelona        88.0
# 3336        3337 2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# 0        2133903.0  2004-06-19   Carmen
# ...

# %% [markdown]
# ### 3.4 Todos los registros con “Provincia” igual a “Girona” y con “Superficie” mayor a “100”

# %%
filtro4 = df[(df['Provincia'] == 'Girona') & (df['Superficie'] > 100)]
display(filtro4)

# Guardar filtro en CSV
filtro4.to_csv("./Filtros/Act1.3/Filtro4.csv")
# Out:
#       Referencia Fecha_Alta        Tipo Operación Provincia  Superficie  \
# 1              2 2004-01-01       Local     Venta    Girona       185.0
# 3              4 2004-01-02     Parking  Alquiler    Girona       285.0
# 5              6 2004-01-03  Industrial  Alquiler    Girona       131.0
# 7              8 2004-01-03     Oficina     Venta    Girona       235.0
# 10            11 2004-01-04     Oficina  Alquiler    Girona       124.0
# ...          ...        ...         ...       ...       ...         ...
# 3299        3300 2007-04-12       Local  Alquiler    Girona       156.0
# 3303        3304 2007-04-12        Piso     Venta    Girona       128.0
# 3306        3307 2007-04-14     Parking     Venta    Girona       221.0
# 3316        3317 2007-04-20        Casa     Venta    Girona       247.0
# 3330        3331 2007-04-27       Local     Venta    Girona       110.0
#
#       Precio Venta Fecha Venta Vendedor
# 1        1945424.0  2004-04-19    Pedro
# ...

# %% [markdown]
# ### 3.5 Todos los registros con “Precio Venta: mayor a 1000,000” o “vendedor” igual a “Carmen o Joaquin”

# %%
filtro5 = df[(df['Precio Venta'] > 1000000) | (df['Vendedor'].isin(['Carmen', 'Joaquín']))]
display(filtro5)

# Guardar filtro en CSV
filtro5.to_csv("./Filtros/Act1.3/Filtro5.csv")
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2 2004-01-01       Local     Venta     Girona       185.0
# 2              3 2004-01-01     Oficina  Alquiler     Girona        82.0
# 7              8 2004-01-03     Oficina     Venta     Girona       235.0
# 8              9 2004-01-04        Piso  Alquiler     Lleida       108.0
# ...          ...        ...         ...       ...        ...         ...
# 3325        3326 2007-04-25  Industrial  Alquiler  Barcelona       296.0
# 3328        3329 2007-04-26        Piso     Venta  Barcelona       264.0
# 3331        3332 2007-04-29     Oficina     Venta     Lleida       190.0
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3336        3337 2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# 0        2133903.0  2004-06-19   Carmen
# ...

# %% [markdown]
# ### 3.6 Todos los registros que no sean de “Provincia : Barcelona“

# %%
filtro6 = df[df['Provincia'] != 'Barcelona']
display(filtro6)

# Guardar filtro en CSV
filtro6.to_csv("./Filtros/Act1.3/Filtro6.csv")
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2 2004-01-01       Local     Venta     Girona       185.0
# 2              3 2004-01-01     Oficina  Alquiler     Girona        82.0
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5 2004-01-02       Suelo     Venta  Tarragona       152.0
# ...          ...        ...         ...       ...        ...         ...
# 3331        3332 2007-04-29     Oficina     Venta     Lleida       190.0
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
# 3334        3335 2007-04-30       Suelo     Venta  Tarragona        78.0
# 3336        3337 2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# 0        2133903.0  2004-06-19   Carmen
# ...

# %% [markdown]
# ### 3.7

# %%
# Filtro con conector logico and, en este caso utilzamos la columna COSTO_TOTAL_CALCULADO y buscamos los valores que sean mayores a 10000, asimismo, utilizamos la columna NOMBRE_VENDEDOR y buscamos la coincidencia con el nombre LETICIA RAMIREZ HERNANDEZ. Ambos parametros deben de cumplirse para guardar el registro
filtro7 = df[(df["COSTO_TOTAL_CALCULADO"] > 10000) & (df["NOMBRE_VENDEDOR"] == "LETICIA RAMIREZ HERNANDEZ")]
display(filtro7)

# Guardar filtro en CSV
filtro7.to_csv("./Filtros/Act1.1/Filtro7.csv")
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 615   F38221 2022-05-24  LETICIA RAMIREZ HERNANDEZ
# 1098  F39183 2022-09-29  LETICIA RAMIREZ HERNANDEZ
# 1101  F39191 2022-09-30  LETICIA RAMIREZ HERNANDEZ
# 1361  F39719 2022-12-07  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT   CVE_ART  \
# 615                  TERMOFORMATEC    60  CAS00080
# 1098    PAULINO ARREDONDO CARDENAS    30  TUA00247
# 1101          CAROLINA PEREZ GOMEZ     2  TUE00382
# 1361  ROSA MARIA HERNANDEZ AGUILAR    25  CBS00092
#
#                                          DESCR  PRECIO_UNITARIO  \
# 615   CAS INOX 18.5MMØX205MM 950W 440V EXT30CM          1296.00
# 1098  TUB INOX 7/16"Øx950mm U 2777W 440V BUSHI          1102.75
# 1101    TUB INOX 1/2"ØX80CM 80KW 440V "U" PLAC         17393.06
# 1361   CBS INOX 20MMØX68CM 1200W 254V EXT.25CM          1457.20
#
#       COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# ...
