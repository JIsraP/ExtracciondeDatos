# %% [markdown]
# #Actividad Extracción de Datos
# -------------------------------------
#
# ####Jose Israel Perez Ontiveros | A01423294

# %% [markdown]
# ## 1. Importar librerias

# %%
import pandas as pd

# %% [markdown]
# ## 2. Carga de archivo XLSX

# %%
df = pd.read_excel('./Recursos/Datos de Facturación.xlsx')
display(df)
# Out:
#       CVE_DOC    CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 0      F29414        2465      C       1.0 2019-09-03 08:58:42.000 2019-09-03
# 1      F29415        3926      C       1.0 2019-09-03 09:55:14.000 2019-09-03
# 2      F29416        3926      C       1.0 2019-09-03 13:25:33.000 2019-09-03
# 3      F29417        3926      C       1.0 2019-09-03 13:33:23.000 2019-09-03
# 4      F29418        6813      C       2.0 2019-09-03 14:23:45.000 2019-09-03
# ...       ...         ...    ...       ...                     ...        ...
# 10890  F40306        8842      E       2.0 2023-03-06 16:09:39.013 2023-03-06
# 10891  F40307        6218    NaN       2.0 2023-03-06 16:38:42.933 2023-03-06
# 10892     NaN        5926      E       2.0 2023-03-06 17:02:33.390 2023-03-06
# 10893  F40309         361      E       2.0 2023-03-07 12:43:49.567 2023-03-07
# 10894  F40310        3011      E       2.0 2023-03-07 12:45:58.407 2023-03-07
#
# ...

# %% [markdown]
# # 3. Filtros

# %% [markdown]
# ### 3.1 CVE_CLPV (valores: 1000 a 2000)

# %%
# Limpieza de datos con replace
df.CVE_CLPV = df.CVE_CLPV.replace({'O':'0'}, regex=False)
df.CVE_CLPV = df.CVE_CLPV.replace({'6781|':'6781'}, regex=False)
df.CVE_CLPV = df.CVE_CLPV.replace({'3612C':'3612'}, regex=False)
df.CVE_CLPV = df.CVE_CLPV.replace({'      ':'0'}, regex=False)
df.CVE_CLPV = df.CVE_CLPV.replace({'2385A':'2385'}, regex=False)
df.CVE_CLPV = df.CVE_CLPV.replace({'2510A':'2510'}, regex=False)
df.CVE_CLPV = df.CVE_CLPV.replace({'8440Q':'8440'}, regex=False)
df.CVE_CLPV = df.CVE_CLPV.replace({'M':'0'}, regex=False)

# Convierte la columna 'CVE_CLPV' a enteros
df['CVE_CLPV'] = df['CVE_CLPV'].astype(float)

# Aplicar Filtro
filtro1 = df[(df['CVE_CLPV'] >= 1000) & (df['CVE_CLPV'] <= 2000)]
display(filtro1)

# Guardar filtro en CSV
filtro1.to_csv("./Filtros/Act1.2/Filtro1.csv")
# Out:
#       CVE_DOC  CVE_CLPV STATUS  CVE_VEND               FECHAELAB  FECHA_DOC  \
# 18     F29432    1965.0      C       2.0 2019-09-05 11:05:04.000 2019-09-05
# 22     F29436    1965.0      C       2.0 2019-09-06 12:01:36.000 2019-09-06
# 65     F29479    1240.0      E       2.0 2019-09-11 18:38:45.000 2019-09-11
# 71     F29485    1965.0      C       2.0 2019-09-12 12:14:28.000 2019-09-12
# 72     F29486    1965.0      E       2.0 2019-09-12 12:25:52.000 2019-09-12
# ...       ...       ...    ...       ...                     ...        ...
# 10821  F40237    1757.0      E       2.0 2023-02-24 15:18:17.570 2023-02-24
# 10839  F40255    1583.0      E       2.0 2023-02-28 09:15:45.753 2023-02-28
# 10845  F40261    1786.0      E       2.0 2023-02-28 11:15:32.527 2023-02-28
# 10871  F40287    1453.0      E       1.0 2023-03-01 12:58:23.397 2023-03-01
# 10876  F40292    1082.0      E       6.0 2023-03-02 11:00:54.770 2023-03-02
#
# ...

# %% [markdown]
# ### 3.2 CVE_VEND (Todas las claves excepto “5” y “4”)

# %%
display(df.groupby(['CVE_VEND'])['CVE_VEND'].count())

# Filtrar las filas donde CVE_VEND no sea "4" ni "5"
filtro2 = df[~df['CVE_VEND'].isin([4, 5])]

display(filtro2.groupby(['CVE_VEND'])['CVE_VEND'].count())

# Guardar filtro en CSV
filtro2.to_csv("./Filtros/Act1.2/Filtro2.csv")
# Out:
# CVE_VEND
# 1.0      959
# 2.0     7706
# 3.0      914
# 4.0      382
# 5.0      423
# 6.0      442
# 7.0        1
# 9.0        1
# 10.0       6
# 11.0      12
# 12.0       1
# Name: CVE_VEND, dtype: int64
# CVE_VEND
# 1.0      959
# 2.0     7706
# 3.0      914
# 6.0      442
# 7.0        1
# 9.0        1
# 10.0       6
# 11.0      12
# 12.0       1
# Name: CVE_VEND, dtype: int64

# %% [markdown]
# ### 3.3 Tercer filtro

# %%
#Filtro por columnas, de la 1 a la 5
filtro3 = df.iloc[:,1:5]
display(filtro3)

# Guardar filtro en CSV
filtro3.to_csv("./Filtros/Act1.1/Filtro3.csv")
# Out:
#       FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  CANT
# 0    2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL     1
# 1    2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE     1
# 2    2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS     7
# 3    2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ     1
# 4    2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL     2
# ...         ...                        ...                           ...   ...
# 1421 2022-12-23  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ     6
# 1422 2022-12-23  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ     6
# 1423 2022-12-23  LETICIA RAMIREZ HERNANDEZ          SEVEN DAYS ALL SPORT     3
# 1424 2022-12-23  LETICIA RAMIREZ HERNANDEZ           REVUELTA MONTECARLO     1
# 1425 2022-12-23         AARON NUÑO CORDOVA                CPEG SOLUTIONS    10
#
# [1426 rows x 4 columns]

# %% [markdown]
# ### 3.4 Cuarto filtro

# %%
#Volvemos a cargar el archivo xlsx para guardarlo en un nuevo DF, pero tomamos en cuenta la primer columna(CVE_DOC) como indice
df1 = pd.read_excel("./Recursos/Detalle precios y productos fabricados 2022.xlsx", index_col=0)

#Filtramos el nombre del vendedor y cliente por el indice indicado
filtro4 = df1.loc[["F39834", "F39837"],["NOMBRE_VENDEDOR", "NOMBRE_CLIENTE"]]
display(filtro4)

# Guardar filtro en CSV
filtro4.to_csv("./Filtros/Act1.1/Filtro4.csv")
# Out:
#                    NOMBRE_VENDEDOR             NOMBRE_CLIENTE
# CVE_DOC
# F39834   LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# F39834   LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# F39837   LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO

# %% [markdown]
# ### 3.5 Quinto filtro

# %%
#Filtrar por medio de la funcion head, que toma los primeros registros. En este caso los primero 10
filtro5 = df.head(10)
display(filtro5)

# Guardar filtro en CSV
filtro5.to_csv("./Filtros/Act1.1/Filtro5.csv")
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8  F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9  F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                   PÚBLICO EN GENERAL     1  TUE00244
# 1         JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 2            ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                 OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4                   PÚBLICO EN GENERAL     2   BP00242
# 5                   PÚBLICO EN GENERAL     2   BP00243
# ...

# %% [markdown]
# ### Sexto filtro

# %%
# Filtro por variables cuantitativas, en este caso la columna de PRECIO_UNITARIO en donde su valor sea mayor a 1000
filtro6 = df[df["PRECIO_UNITARIO"] > 1000]
display(filtro6)

# Guardar filtro en CSV
filtro6.to_csv("./Filtros/Act1.1/Filtro6.csv")
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 10    F37050 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                            NOMBRE_CLIENTE  CANT   CVE_ART  \
# 1            JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 8                      FIDEICOMISO F/1596     1  TUE00207
# 9                      FIDEICOMISO F/1596     1  TUE00207
# ...

# %% [markdown]
# ### Septimo filtro

# %%
# Filtro con conector logico and, en este caso utilzamos la columna COSTO_TOTAL_CALCULADO y buscamos los valores que sean mayores a 10000, asimismo, utilizamos la columna NOMBRE_VENDEDOR y buscamos la coincidencia con el nombre LETICIA RAMIREZ HERNANDEZ. Ambos parametros deben de cumplirse para guardar el registro
filtro7 = df[(df["COSTO_TOTAL_CALCULADO"] > 10000) & (df["NOMBRE_VENDEDOR"] == "LETICIA RAMIREZ HERNANDEZ")]
display(filtro7)

# Guardar filtro en CSV
filtro7.to_csv("./Filtros/Act1.1/Filtro7.csv")
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 615   F38221 2022-05-24  LETICIA RAMIREZ HERNANDEZ
# 1098  F39183 2022-09-29  LETICIA RAMIREZ HERNANDEZ
# 1101  F39191 2022-09-30  LETICIA RAMIREZ HERNANDEZ
# 1361  F39719 2022-12-07  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT   CVE_ART  \
# 615                  TERMOFORMATEC    60  CAS00080
# 1098    PAULINO ARREDONDO CARDENAS    30  TUA00247
# 1101          CAROLINA PEREZ GOMEZ     2  TUE00382
# 1361  ROSA MARIA HERNANDEZ AGUILAR    25  CBS00092
#
#                                          DESCR  PRECIO_UNITARIO  \
# 615   CAS INOX 18.5MMØX205MM 950W 440V EXT30CM          1296.00
# 1098  TUB INOX 7/16"Øx950mm U 2777W 440V BUSHI          1102.75
# 1101    TUB INOX 1/2"ØX80CM 80KW 440V "U" PLAC         17393.06
# 1361   CBS INOX 20MMØX68CM 1200W 254V EXT.25CM          1457.20
#
#       COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# ...

# %% [markdown]
# ### Octavo filtro

# %%
# Filtro con conector logico or, en este caso utilzamos la columna COSTO_TOTAL_CALCULADO y buscamos los valores que sean menores a 100, asimismo, utilizamos la columna FECHA_DOC y buscamos la coincidencia con la fecha 2022-12-23. Con uno de los parametros que se cumpla el registro se guardarda
filtro8 = df[(df["COSTO_TOTAL_CALCULADO"] < 100) | (df["FECHA_DOC"] == "2022-12-23")]
display(filtro8)

# Guardar filtro en CSV
filtro8.to_csv("./Filtros/Act1.1/Filtro8.csv")
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ         PÚBLICO EN GENERAL
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN       OMAR RODRIGUEZ GOMEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ         PÚBLICO EN GENERAL
# 13    F37053 2022-01-05   DIEGO ARMANDO LEON DURAN  SANDIBEEL BECERRA HURTADO
# 20    F37061 2022-01-05             ALFREDO CANELA                   ELICAMEX
# ...      ...        ...                        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
# ...

# %% [markdown]
# ### Noveno filtro

# %%
#Filtro con conector logico not, en este caso utilzamos la columna COSTO_TOTAL_CALCULADO y buscamos los valores que no sean menores a 100, asimismo, utilizamos la columna FECHA_DOC y buscamos que no coincidencia con la fecha 2022-12-23. Ambos parametros deben de cumplirse para guardar el registro
filtro9 = df[~(df["COSTO_TOTAL_CALCULADO"] < 100) & ~(df["FECHA_DOC"] == "2022-12-23")]
display(filtro9)

# Guardar filtro en CSV
filtro9.to_csv("./Filtros/Act1.1/Filtro9.csv")
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1406  F39813 2022-12-22  LETICIA RAMIREZ HERNANDEZ
# 1407  F39815 2022-12-22             ALFREDO CANELA
# 1409  F39816 2022-12-22             ALFREDO CANELA
# 1410  F39817 2022-12-22  LETICIA RAMIREZ HERNANDEZ
# 1411  F39820 2022-12-22         AARON NUÑO CORDOVA
#
#                                          NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1                          JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2                             ANA BARBARA CRUZ PALACIOS     7        TP0007
# 4                                    PÚBLICO EN GENERAL     2       BP00242
# ...
